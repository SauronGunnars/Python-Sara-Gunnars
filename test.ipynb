# %%
print("hej")

x = 2
x**2
# Out:
# hej
# 4

# %%
# Test of the zip function
numbers = [1,2,3]
str_number = ['one', 'two', 'three']

zipped = zip(numbers, str_number)
print(zipped)
print(list(zipped))
# Out:
# ...
# [(1, 'one'), (2, 'two'), (3, 'three')]

# %%
import matplotlib.pyplot as plt

f = lambda x: x**2
y = [f(x) for x in range(-5,5)]
x = range (-5,5)

plt.plot(x,y)
